# %%
import requests

# %%
url = 'http://127.0.0.1:5000/predict'

# %%
data = {
    "Pregnancies": 0,
    "Glucose": 90,
    "BloodPressure": 70,
    "SkinThickness": 20,
    "Insulin":100,
    "BMI":225.6,
    "DiabetesPedigreeFunction": 0.250,
    "Age":30
}

# %%
response = requests.post(url, json=data)
print(response.text)
# Out:
# {
#   "prediction": "Diabetes"
# }
